# %% [markdown]
# # Types of Machine Learning

# %% [markdown]
# ## Definition of Machine Learning

# %% [markdown]
# "A computer program is said to learn from **Experience E** with respect to some class of **tasks T** and **performance measure P** if its performance at tasks in T, as measured by P, *improves* with experience E" (Mitchell et al, 1997)

# %% [markdown]
# ## Supervised Learning
#
# - Regression (real-valued or continuous value) or Classification (Categoril or 1 of N)
# - Requires data with ground-truth labels/outputs

# %% [markdown]
# ## Unsupervised Learning
# - Self-supervised or semi-supervised learning
# - Requires observations WITHOUT human annotations

# %% [markdown]
# ## Reinforcement Learning

# %% [markdown]
# - Sparse rewards from environment (e.g. won/lost)
# - Actions affects the environment (dynamic nature)

# %% [markdown]
# ## Train/Validation/Test Splits

# %% [markdown]
# We cannot use all data for training.
#
# We need:
#
# 1. **Training Data**: What the model will be trained on
# 2. **Validation Data**: Used for evaluation during training
# 3. **Testing Data**: Used for final inferencing

# %% [markdown]
# ![image.png](attachment:image.png)
